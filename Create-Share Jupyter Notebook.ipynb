# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Fits Kebede**

# %% [markdown]
# IT Trainer

# %% [markdown]
# _I am an IT Trainer and pursuing to the data science trainer profession. My interest in data science is due to my research on machine learning during my PhD project._

# %% [markdown]
# # <font color=blue>Assignment</font>

# %% [markdown]
# **Numerical Operation**

# %% [markdown]
# The following script willl display will Find 25% of 10

# %%
25/100 * 10
# Out:
# 2.5

# %% [markdown]
# **Bulleted list**

# %% [markdown]
# <ul>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ul>

# %% [markdown]
# **Listing numbers**

# %% [markdown]
# Python-Libraries
#   1. Panda
#
#   2. Matlab

# %% [markdown]
# **Insert Image- Silent Image**

# %% [markdown]
# ![Silent Image](attachment:Zimita%20new%20melse.png)

# %% [markdown]
# **Juypter Notebook Markdown reference HyperLink**

# %% [markdown]
# [Markdown reference](https://www.tutorialspoint.com/jupyter/jupyter_notebook_markdown_cells.htm)
